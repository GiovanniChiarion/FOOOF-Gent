# %%
# %matplotlib inline

# %% [markdown]
# # N170 Load and Visualize Data
#
# This example demonstrates loading, organizing, and visualizing ERP response data from the visual N170 experiment.
#
# Images of faces and houses are shown in a rapid serial visual presentation (RSVP) stream.
#
# The data used is the first subject and first session of the one of the eeg-notebooks N170 example datasets, recorded using the InteraXon MUSE EEG headset (2016 model).
# This session consists of six two-minute blocks of continuous recording.
#
# We first use the `fetch_datasets` to obtain a list of filenames. If these files are not already present
# in the specified data directory, they will be quickly downloaded from the cloud.
#
# After loading the data, we place it in an MNE `Epochs` object, and obtain the trial-averaged response.
#
# The final figure plotted at the end shows the N170 response ERP waveform.

# %% [markdown]
# ## Setup

# %%
# Some standard pythonic imports
import os
from collections import OrderedDict
import warnings
warnings.filterwarnings('ignore')

# MNE functions
from mne import Epochs,find_events

# EEG-Notebooks functions
from eegnb.analysis.utils import load_data,plot_conditions
from eegnb.datasets import fetch_dataset

# %% [markdown]
# ## Load Data
#
# We will use the eeg-notebooks N170 example dataset
#
# Note that if you are running this locally, the following cell will download
# the example dataset, if you do not already have it.

# %%
eegnb_data_path = os.path.join(os.path.expanduser('~/'),'.eegnb', 'data')    
n170_data_path = os.path.join(eegnb_data_path, 'visual-N170', 'eegnb_examples')

# If dataset hasn't been downloaded yet, download it 
if not os.path.isdir(n170_data_path):
    fetch_dataset(data_dir=eegnb_data_path, experiment='visual-N170', site='eegnb_examples');

subject = 1
session = 1
raw = load_data(subject,session,
                experiment='visual-N170', site='eegnb_examples', device_name='muse2016_bfn',
                data_dir = eegnb_data_path)
# Out:
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=93280
#     Range : 0 ... 93279 =      0.000 ...   364.371 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=76768
#     Range : 0 ... 76767 =      0.000 ...   299.871 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=76744
#     Range : 0 ... 76743 =      0.000 ...   299.777 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=76912
#     Range : 0 ... 76911 =      0.000 ...   300.434 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ...

# %% [markdown]
# ## Visualize the power spectrum

# %%
raw.plot_psd()
# Out:
# Effective window size : 8.000 (s)
# <MNELineFigure size 720x252 with 2 Axes>
# <MNELineFigure size 720x252 with 2 Axes>

# %% [markdown]
# ## Filtering

# %%
raw.filter(1,30, method='iir')
raw.plot_psd(fmin=1, fmax=30);
# Out:
# Filtering raw data in 10 contiguous segments
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# Effective window size : 8.000 (s)
# <MNELineFigure size 720x252 with 2 Axes>

# %% [markdown]
# ## Epoching

# %%
# Create an array containing the timestamps and type of each stimulus (i.e. face or house)
events = find_events(raw)
event_id = {'House': 1, 'Face': 2}

# Create an MNE Epochs object representing all the epochs around stimulus presentation
epochs = Epochs(raw, events=events, event_id=event_id, 
                tmin=-0.1, tmax=0.6, baseline=None,
                reject={'eeg': 5e-5}, preload=True, 
                verbose=False, picks=[0,1,2,3])
print('sample drop %: ', (1 - len(epochs.events)/len(events)) * 100)
epochs
# Out:
# 3740 events found
# Event IDs: [1 2]
# sample drop %:  9.919786096256688
# <Epochs |  3369 events (all good), -0.101562 - 0.601562 sec, baseline off, ~18.6 MB, data loaded,
#  'House': 1667
#  'Face': 1702>

# %% [markdown]
# ## FOOF AVERAGING EPOCHS

# %%
from fooof import FOOOF, FOOOFGroup
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
from mne.time_frequency import psd_welch
from fooof.plts import plot_spectra, plot_spectrum

fs = 256

# Set peak_width_limits
pwl = [2, 4]

# Set max_n_peaks
mnp = 5

# Set peak_threshold
pt = 2 

max_freq = 30

av_epochs = epochs.average(picks=[0,1,2,3],by_event_type=True)
fms = list()
powers = list()

for i,e in enumerate(av_epochs):
    e.plot(spatial_colors=True)
    power, freq = psd_welch(e, n_fft=len(e.times), n_overlap=np.floor(len(e.times)/2),\
    proj=False, average='mean', window='hamming',verbose=None)
    plot_spectrum(freq[(freq>0) & (freq<max_freq)],power[3,(freq>0) & (freq<max_freq)],log_powers=True)
    powers.append(power)
    
    # fms.append(FOOOF(aperiodic_mode='knee', max_n_peaks=mnp, peak_threshold=pt, verbose=True))
    fms.append(FOOOF(aperiodic_mode='knee', verbose=True))
    fms[i].fit(freq, power[3],freq_range=[0,max_freq]) # !!!!Only a channel for now!!!!
    fms[i].print_results()
    fig, ax = plt.subplots(figsize=[15, 5])
    fms[i].plot(plot_peaks='line-shade', ax=ax)
# Out:
# Effective window size : 0.707 (s)
#
# FOOOF WARNING: Skipping frequency == 0, as this causes a problem with fitting.
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 1.41 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ...
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 30 Hz
#                                  Frequency Resolution is 1.41 Hz
#
#                          Aperiodic Parameters (offset, knee, exponent):
#                                     -11.0558, 40.5313, 3.7963
#
#                                        2 peaks were found:
#                                 CF:   8.92, PW:  1.332, BW:  3.63
# ...

# %%
labels = ["House","Face"]
fig, ax = plt.subplots(figsize=[15, 5])
plot_spectra(fms[0].freqs,[fms[0].power_spectrum,fms[1].power_spectrum],ax=ax,labels=labels)
plt.title("Original Spectra")

fig, ax = plt.subplots(figsize=[15, 5])
plot_spectra(fms[0].freqs,[fms[0]._peak_fit,fms[1]._peak_fit],ax=ax,labels=labels)
plt.title("Peak Fit")

fig, ax = plt.subplots(figsize=[15, 5])
plot_spectra(fms[0].freqs,[fms[0]._ap_fit,fms[1]._ap_fit],ax=ax,labels=labels)
plt.title("AP Fit")

fig, ax = plt.subplots(figsize=[15, 5])
plot_spectra(fms[0].freqs,[fms[0]._spectrum_flat,fms[1]._spectrum_flat],ax=ax,labels=labels)
plt.title("Flattened Spectrum")

fig, ax = plt.subplots(figsize=[15, 5])
plot_spectra(fms[0].freqs,[fms[0]._spectrum_peak_rm,fms[1]._spectrum_peak_rm],ax=ax,labels=labels)
plt.title("Peak Removed")
# Out:
# Text(0.5, 1.0, 'Peak Removed')

# %% [markdown]
# ## FOOOF USING GROUPS

# %%
# for k in event_id.keys():
#     powers, freq = psd_welch(epochs[k], n_fft=len(epochs.times), n_overlap=np.floor(len(epochs.times)/2),\
#     proj=False, average='mean', window='hamming',verbose=None)
    
#     plot_spectrum(freq[(freq>0) & (freq<max_freq)],powers[0,3,(freq>0) & (freq<max_freq)],log_powers=True)

# %% [markdown]
# ## CANNOT PERFORM GROUP ANALYSIS SINCE THE EPOCHS ARE TOO SHORT AND NOISY

# %%
# from fooof.objs import fit_fooof_3d, combine_fooofs
# from fooof.core.errors import FitError

# fg = FOOOFGroup(aperiodic_mode='knee', max_n_peaks=mnp, peak_threshold=pt, verbose=True)
# # fg.set_debug_mode(True)

# for k in event_id.keys():
#     powers, freq = psd_welch(epochs[k], n_fft=len(epochs.times), n_overlap=np.floor(len(epochs.times)/2),\
#     proj=False, average='mean', window='hamming',verbose=None)
    
#     fgs = fit_fooof_3d(fg,freq,powers,freq_range=[0,max_freq])

#     all_fg = combine_fooofs(fgs)
#     all_fg.print_results()
#     all_fg.plot()

# %% [markdown]
# ## Epoch average

# %%
conditions = OrderedDict()
conditions['House'] = [1]
conditions['Face'] = [2]

fig, ax = plot_conditions(epochs, conditions=conditions, 
                          ci=97.5, n_boot=1000, title='',
                          diff_waveform=None, #(1, 2))
                          channel_order=[1,0,2,3]) # reordering of epochs.ch_names according to [[0,2],[1,3]] of subplot axes

# Manually adjust the ylims
for i in [0,2]: ax[i].set_ylim([-0.5,0.5])
for i in [1,3]: ax[i].set_ylim([-1.5,2.5])

# %%
from mne.viz import plot_compare_evokeds
face = epochs["Face"].average()
house = epochs["House"].average()

plot_compare_evokeds(dict(Face=face,House=house),show_sensors="upper right",picks="TP9")
face.plot_joint()
face.plot_topomap()
# Out:
# No projector specified for this dataset. Please consider the method self.add_proj.
# <MNEFigure size 540x158.4 with 5 Axes>
# <MNEFigure size 540x158.4 with 5 Axes>

# %% [markdown]
# ## PROVE

# %%
import numpy as np

a = np.array(((1,2)))
b = np.array(((3,4)))
c = (a,b)
print(c)
d = np.hstack((a,b))
print(d)
